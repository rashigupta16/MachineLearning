# %%
import sys
sys.path.insert(0, '/usr/local/lib/python2.7/site-packages')
import pandas as pd
import numpy as np

# %%
training = pd.read_csv("Titanic_train.csv")
testing = pd.read_csv("Titanic_test.csv")
trainingids= training["PassengerId"]
testingids= testing["PassengerId"]
training.drop("PassengerId",1, inplace=True)
indexes= testing["PassengerId"]
testing.drop("PassengerId",1, inplace= True)

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB

# %%
training
# X= training.drop("Survived",1)
# Y= training["Survived"]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
training
training.drop("Name",1, inplace=True)
# training.drop("Ticket", 1, inplace=True)
testing.drop("Name",1, inplace=True)
# testing.drop("Ticket", 1, inplace=True)

# %%
from sklearn import preprocessing
con = preprocessing.LabelEncoder()
training["Sex"]= con.fit_transform(training["Sex"])
testing["Sex"]= con.fit_transform(testing["Sex"])
label = list(training)
# for c in label:
#     print(c, pd.isnull(training[c]).sum())
mean_age= training["Age"].mean()
training["Age"].fillna(mean_age,inplace=True)
training["Embarked"].fillna(training["Embarked"].max(),inplace=True)
training["Cabin"].fillna(-1000)
training["Cabin"]= con.fit_transform(training["Cabin"])
training["Embarked"]= con.fit_transform(training["Embarked"])
training["Ticket"]=con.fit_transform(training["Ticket"])

mean_age= testing["Age"].mean()
testing["Age"].fillna(mean_age,inplace=True)
testing["Embarked"].fillna(testing["Embarked"].max(),inplace=True)
testing["Fare"].fillna(testing["Fare"].mean(),inplace=True)
testing["Cabin"].fillna(-1000, inplace=True)
testing["Cabin"]= con.fit_transform(testing["Cabin"])
testing["Embarked"]= con.fit_transform(testing["Embarked"])
testing["Ticket"]=con.fit_transform(testing["Ticket"])
label= list(testing)
for c in label:
    print(c, pd.isnull(testing[c]).sum())
# Out:
# ('Pclass', 0)
# ('Sex', 0)
# ('Age', 0)
# ('SibSp', 0)
# ('Parch', 0)
# ('Ticket', 0)
# ('Fare', 0)
# ('Cabin', 0)
# ('Embarked', 0)

# %%
training.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   13.002015    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#            Ticket        Fare       Cabin    Embarked
# count  891.000000  891.000000  891.000000  891.000000
# mean   338.528620   32.204208   17.629630    1.536476
# std    200.850657   49.693429   38.140335    0.791503
# ...

# %%
testing.info()
# training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# Pclass      418 non-null int64
# Sex         418 non-null int64
# Age         418 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null int64
# Fare        418 non-null float64
# Cabin       418 non-null int64
# Embarked    418 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 29.5 KB

# %%
from sklearn import cross_validation
X= training.drop("Survived",1)
print(type(X))
Y= training["Survived"]
X= preprocessing.scale(X)
x= preprocessing.scale(testing)
# x= preprocessing.scale(x)
# X_Train, X_Test, Y_Train, Y_Test= cross_validation.train_test_split(X,Y,test_size=0.02)
# print(X_Train.shape, X_Test.shape, Y_Train.shape, Y_Test.shape)
# from sklearn.feature_selection import RFE
# from sklearn.svm import SVR
# estimator = SVR(kernel="linear")
# selector = RFE(estimator, 5, step=1)
# selector = selector.fit(X, Y)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# from sklearn.feature_selection import RFE
# from sklearn.svm import SVR
# model=SVR(kernel="linear")
# selector= RFE(model, 1)
# selector.fit(X_Train, Y_Train)
# print (label)
# selector.ranking_
# print (selector.score(X_Test, Y_Test))

# %%
from sklearn.neighbors import KNeighborsClassifier
# neigh = KNeighborsClassifier(n_neighbors=3)
# neigh.fit(X_Train ,Y_Train)
# neigh.score(X_Test, Y_Test)
#0.77777777777777779

# %%
# from sklearn import tree
# clf = tree.DecisionTreeClassifier()
# clf = clf.fit(X_Train,Y_Train)
# clf.score(X_Test, Y_Test)
# 0.72222222222222221

# %%
# from sklearn.ensemble import RandomForestClassifier
# clf = RandomForestClassifier(n_estimators=53)
# clf = clf.fit(X_Train, Y_Train)
# clf.score(X_Test,Y_Test)
# 0.77777777777777779

# %%
from sklearn.ensemble import RandomForestClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X ,Y)
a= neigh.predict(x)
# print(indexes)
result= np.zeros((len(indexes),2), dtype='int')

result[:,1]=a
result[:,0]= np.array(indexes)
print(result)
np.savetxt('my_results.csv', result, delimiter=',', fmt="%i", header='labels')
# Out:
# [[ 892    0]
#  [ 893    0]
#  [ 894    0]
#  [ 895    0]
#  [ 896    0]
#  [ 897    0]
#  [ 898    1]
#  [ 899    0]
#  [ 900    1]
#  [ 901    0]
#  [ 902    0]
#  [ 903    0]
#  [ 904    1]
#  [ 905    0]
#  [ 906    0]
#  [ 907    1]
#  [ 908    0]
#  [ 909    0]
#  [ 910    0]
#  [ 911    1]
#  [ 912    0]
#  [ 913    1]
#  [ 914    1]
#  [ 915    0]
#  [ 916    1]
#  [ 917    0]
#  [ 918    1]
#  [ 919    0]
#  [ 920    1]
#  [ 921    0]
#  [ 922    0]
#  [ 923    0]
#  [ 924    1]
#  [ 925    0]
#  [ 926    1]
#  [ 927    0]
#  [ 928    0]
#  [ 929    1]
#  [ 930    0]
#  [ 931    1]
#  [ 932    0]
#  [ 933    1]
#  [ 934    0]
#  [ 935    1]
#  [ 936    1]
#  [ 937    0]
#  [ 938    0]
#  [ 939    0]
#  [ 940    1]
#  [ 941    1]
#  [ 942    0]
#  [ 943    0]
#  [ 944    1]
#  [ 945    1]
#  [ 946    0]
#  [ 947    0]
#  [ 948    0]
#  [ 949    0]
#  [ 950    0]
#  [ 951    1]
#  [ 952    0]
#  [ 953    1]
#  [ 954    0]
#  [ 955    1]
#  [ 956    1]
#  [ 957    1]
# ...
